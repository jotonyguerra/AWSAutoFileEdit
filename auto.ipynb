# %%
import cv2
import glob 
import numpy as np
import pandas as pd
import csv 
import sys
import os
from PIL import Image, ImageOps
from pathlib import Path

# %%
#IMAGES_FOLDER = input("Enter path to folder with images (.png or .jpg):")
#print("File Path Entered: ", IMAGES_FOLDER)
    # test to see if file path is stored correctly

#function to read folder and return jpeg images 
def read_Image_Folder(folder):
    #data array 
    X_data = []
    #grab all files from directory with jpg extension
    files = glob.glob (str(folder)+'/*jpg')
    #print all file names/ read images and append to array
    for myFile in files:
        print(myFile)
        #image = cv2.imread (myFile)
        #X_data.append (image)
    return #X_data
#function returns the array containing the images. Can iterate through the array to use those images in other functions

# %%
from PIL import Image

if not os.path.exists('test'):
    os.makedirs('test')

#function to modify frame image and store into the newly created directory 
#Returns the keyname for each and every model created. s
def modify12x16Frame(frameImage, inputImage):
    list = []
    frameBF = Image.open(frameImage) #open Black Flat
    bb1216 = r'12x16 Black Bevel\12x16 Black Bevel\1 Main.jpeg' #path to beveled black
    wf1216 = r'12x16 White Flat\12x16 White Flat\1 Main.jpeg' #path to flat white frame
    gf1216 = r'12x16 Grey Flat\12x16 Grey Flat\1 Main.jpeg'
    frameBB1216 = Image.open(bb1216) #opens the black beveled fram 12 x 16
    frameWF1216 = Image.open(wf1216) 
    frameGF1216 = Image.open(gf1216)

    innerImg = Image.open(inputImage) #open insert image that will go into frame 
    inSize = ((1130),(1530)) #size to expand the image to fit in the frame
    reSized = innerImg.resize(inSize) #resize the insert image to fit the frame
    reSizedBB = innerImg.resize((1049,1365))
    reSizedWF = innerImg.resize((1094, 1486))
    reSizedGF = innerImg.resize((1082, 1465))
    #jpg = ".jpg"
    frameBF.paste(reSized, (558,361)) #paste new resized image into the frame
    frameBB1216.paste(reSizedBB,(600,438)) #paste new resized image into black beveled frame.
    frameWF1216.paste(reSizedWF, (586, 360)) #may need to move down a pixel. Cant tell cuz of blur.
    frameGF1216.paste(reSizedGF, (581, 390))
    
    frameBF.save(fp="./test/" + os.path.basename(inputImage))
    frameBB1216.save(fp="./test/BB1216" + os.path.basename(inputImage))
    frameWF1216.save(fp="./test/WF1216" + os.path.basename(inputImage))
    frameGF1216.save(fp="./test/GF1216" + os.path.basename(inputImage))
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\BF1216'
    dir_name2 = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\BB1216'
    dir_name3 = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\WF1216'
    dir_name4 = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\GF1216'
    keyName = os.path.join(dir_name, os.path.basename(inputImage))
    keyNameBB = os.path.join(dir_name2, os.path.basename(inputImage))
    keyNameWF = os.path.join(dir_name3, os.path.basename(inputImage))
    keyNameGF = os.path.join(dir_name4, os.path.basename(inputImage))
    print("Files saved and changed")
    list.append(keyName)
    list.append(keyNameBB)
    list.append(keyNameGF)
    list.append(keyNameWF)
    return list

##Function to modify landscape 12x16 frames. 
#Will open all frame images, Black beveled, Black Flat, and Grey Flat and will place the image in the frame.
#
#
##
def landscapeFrame(inputImg):
    #frameBF = Image.open(frameLandScapeImage) #open landscape frame
    pathBB1216 = r'12x16 Black Bevel\12x16 Black Bevel\11 Main.jpeg' #path to black beveled landscape frame
    pathBF1216 = r'12x16 Black Flat\12x16 Black Flat\11 Main.jpeg' #path to Black Flat Frame
    pathGF1216 = r'12x16 Grey Flat\12x16 Grey Flat\11 Main.jpeg' #path to Grey Flat Frame
    pathWF1216 = r'12x16 White Flat\12x16 White Flat\11 Main.jpeg'
    frameBB1216 = Image.open(pathBB1216) #opens the black beveled fram 12 x 16
    frameBF = Image.open(pathBF1216)
    frameWF1216 = Image.open(pathWF1216) 
    frameGF1216 = Image.open(pathGF1216)

    #rgb_im = frame.convert('RGB')
    innerImg = Image.open(inputImg) #open insert image that will go into frame 
    inSize = (1536, 1140) 
    reSized = innerImg.resize((inSize))

    reSizedBB = innerImg.resize((1497,1147))
    reSizedWF = innerImg.resize((1492, 1096))
    reSizedGF = innerImg.resize((1468, 1086))

    frameBF.paste(reSized, (363, 551)) #paste new resized image into the frame
    frameWF1216.paste(reSizedWF, (398,585)) #paste resized image into White frame
    frameBB1216.paste(reSizedBB, (375,550))
    frameGF1216.paste(reSizedGF, (392,579))
    #ignore, saveName = inputImg.split(".", 1)
    frameBF.save(fp="./test/" + os.path.basename(inputImg))
    frameBB1216.save(fp="./test/BB1216_Landscape" + os.path.basename(inputImg))
    frameWF1216.save(fp="./test/WF1216_Landscape" + os.path.basename(inputImg))
    frameGF1216.save(fp="./test/GF1216_Landscape" + os.path.basename(inputImg))
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\BF1216_Landscape'
    dir_name2 = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\BB1216_Landscape'
    dir_name3 = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\WF1216_Landscape'
    dir_name4 = r'C:\Users\joton\OneDrive\Documents\Automation Project\test\GF1216_Landscape' #function. 
    keyName = os.path.join(dir_name, os.path.basename(inputImg))
    keyNameBB = os.path.join(dir_name2, os.path.basename(inputImg))
    keyNameWF = os.path.join(dir_name3, os.path.basename(inputImg))
    keyNameGF = os.path.join(dir_name4, os.path.basename(inputImg))
    print("File saved and changed")
        print("Files saved and changed")
    list.append(keyName)
    list.append(keyNameBB)
    list.append(keyNameGF)
    list.append(keyNameWF)
    return list

#testname = modify12x16Frame(frameImage = './Main Image Vertical.jpeg', inputImage = 'oceanTest.jpg')
#print(testname)
#frameimage = r'12x16 Black Flat\12x16 Black Flat\1 Main.jpeg'
#modify12x16Frame(frameImage = frameimage, inputImage = 'testImages\Sunflowers_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg')
landscapeFrame(inputImg='Vincent Van Gogh  - 1888 - Fishing Boats At Sea.jpeg')
# Out:
# File saved and changed
# ('C:\\Users\\joton\\OneDrive\\Documents\\Automation Project\\test\\BF1216_Landscape\\Vincent Van Gogh  - 1888 - Fishing Boats At Sea.jpeg',
#  'C:\\Users\\joton\\OneDrive\\Documents\\Automation Project\\test\\BB1216_Landscape\\Vincent Van Gogh  - 1888 - Fishing Boats At Sea.jpeg',
#  'C:\\Users\\joton\\OneDrive\\Documents\\Automation Project\\test\\WF1216_Landscape\\Vincent Van Gogh  - 1888 - Fishing Boats At Sea.jpeg',
#  'C:\\Users\\joton\\OneDrive\\Documents\\Automation Project\\test\\GF1216_Landscape\\Vincent Van Gogh  - 1888 - Fishing Boats At Sea.jpeg')

# %%
def modify2Dmodel(modelImg, inputImage):
    modelImage = Image.open(modelImg) #open image with model 
    rgb_im = modelImage.convert('RGB')
    
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    reSize = ((937-669),(273-34))
    resizeImg = innerImg.resize(reSize)
    rgb_im.paste(resizeImg, (669,34))
    ignore, saveName = inputImage.split("/", 1)
    rgb_im.save(fp="2D Model " + saveName)
    print("Pasted and saved")
    return


def modifyBackgroundLS(inputImg):
    modelImage = Image.open(r"C:\Users\joton\OneDrive\Documents\Automation Project\Copy of Background%202_photos_v2_x4.jpg")
    rgb_im = modelImage.convert('RGB')
    innerImg = Image.open(inputImg)
    newImg = ImageOps.crop(innerImg, (281,0,195,0))
    #innerImg = innerImg.crop((251,0, 1760,0))
    reSize = ((1350-900),(650-200))
    resizeImg = newImg.resize(reSize)

    text_img = Image.new('RGB', (2000,2000), (0, 0, 0, 0))
    text_img.paste(rgb_im, (0,0)) # paste lifestyle photo into background
    text_img.paste(resizeImg,(900,200))

    #rgb_im.paste(resizeImg, (900,200))
    p = Path(inputImg)
    
    text_img.save(fp="Lifestyle_1_" + p.name)
    print("Pasted and saved")
    return

if not os.path.exists('VVG-Horizontal'):
    os.makedirs('VVG-Horizontal')

#function to paste image into Number 2 
def number2VertHorizontal(inputImage):
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    width, height = innerImg.size 
    if width > height:
        modelImage = Image.open('Number 2 Horiz.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (1338,1028) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (426,585))
    else:
        modelImage = Image.open('Number 2 Vert.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (1026,1338) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (587,425))
    namename, saveName = inputImage.split(".", 1)
    #print("Savename = ", saveName)
    rgb_im.save(fp="./test/Number2" + os.path.basename(inputImage))
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test' 
    fileBase = 'Number2' + os.path.basename(inputImage)
    keyName = os.path.join(dir_name, fileBase)
    print("Pasted and saved")
    return keyName

def number3VertHorizontal(inputImage):
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    width, height = innerImg.size 
    if width > height:
        modelImage = Image.open('Number 3 Horiz.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (475,350) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (526,324))
    else:
        modelImage = Image.open('Number 3 Vert.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (355,471) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (588,261))
    namename, saveName = inputImage.split(".", 1)
    rgb_im.save(fp="./test/Number3New_" + os.path.basename(inputImage))
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test' #this should be a constant of some sort as its being accessed in every function. 
    keyName = os.path.join(dir_name, os.path.basename(inputImage)) #code is repeating so gotta clean this up.
    print("Pasted and saved")
    return keyName 

def number4VertHorizontal(inputImage):
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    width, height = innerImg.size 
    if width > height:
        modelImage = Image.open('Number 4 Horiz.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (492,378) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (1092,402))
    else:
        modelImage = Image.open('Number 4 Vert.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (379,494) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (1150,342))
    namename, saveName = inputImage.split(".", 1)
    rgb_im.save(fp="./test/number4_" + os.path.basename(inputImage))
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test' #this should be a constant of some sort as its being accessed in every function. 
    keyName = os.path.join(dir_name, os.path.basename(inputImage))
    print("Pasted and saved")
    return keyName

#number2VertHorizontal("Vincent Van Gogh - 1890 - Wheat Field With Crows.jpeg")
#number3VertHorizontal("Vincent Van Gogh - 1890 - Wheat Field With Crows.jpeg")
#number4VertHorizontal('Vincent Van Gogh - 1890 - Wheat Field With Crows.jpeg')
#from pathlib import Path
#p = Path(r"C:\Users\joton\OneDrive\Documents\Automation Project\update_images_folder\12 x 16 oceanTest.jpg")
#modifyBackgroundLS(str(p))

# %%
#create randomly SKU number
import secrets 
import string 
# initializing size of string 
def randomSKU():
    N = 12
# generating random strings  
    #INput should apply to all LISTING in the CSV/EXCEL FILE.
    res = ''.join(secrets.choice(string.ascii_uppercase + string.digits) for i in range(N)) 
    prompt = input("Enter any additional SKU. Will appear as 'F1-(input)-random_letters_and_numbers' :")
    #Need Conditional for different scenarios 
    return "F1-" + prompt + str(res)

# %%
#path should be input arguments 
#hard coded for now
import openpyxl
from openpyxl import Workbook
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font
from pathlib import Path
from datetime import date
filename = "C:/Users/joton/OneDrive/Documents/Automation Project/CSV Template.xlsx"

#function creates excel/csv for Black Beveled 12 x 16
#function to write urls and info into csv/excel file #write for b
def write_to_excel(nameOfImage, mainImage, number2Image, number3Image, number4Image, number5Image, count, colorname, gw="Print Size 12 x 16 Frame Size 14.5 x 18.5"):
    #data = pd.read_excel(filename)
    #data.to_excel('test_write_excel.xlsx', index=False)
    wb = load_workbook(filename = 'new_test.xlsx')
    ws = wb.active
    # ws.delete_rows(4, 3)
    rowNum = 5 + count
    #print("Rown Num = ", rowNum)
    ws.cell(row=rowNum, column=1).value = 'Home'
    ws.cell(row=rowNum, column=2).value = randomSKU()
    ws.cell(row=rowNum, column=4).value = nameOfImage 
    ws.cell(row=rowNum, column=12).value = mainImage    #
    ws.cell(row=rowNum, column=13).value = number2Image #
    ws.cell(row=rowNum, column=14).value = number3Image #
    ws.cell(row=rowNum, column=15).value = number4Image #
    ws.cell(row=rowNum, column=16).value = number5Image #
    #if()
    ws.cell(row=rowNum, column=17).value = number7Image # 
    #ws.cell(row=rowNum, column=18).value = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Number+7.jpeg'
    ws.cell(row=rowNum, column=113).value = colorname
    ws.cell(row=rowNum, column=115).value = '14.5 x 18.5 inches' #DK size_name
    ws.cell(row=rowNum, column=145).value = "18.5 inches"#EO length range
    ws.cell(row=rowNum, column=146).value = "16.5 inches"#EP Width Range
    #ws.cell(row=rowNum, column=205).value = 'Print Size 12" x 16" Frame Size 14.5" x 18.5"' #GW Width Range 
    ws.cell(row=rowNum, column=169).value = 1.70    #Shipping weight FM
    ws.cell(row=rowNum, column=169).value = 'LB'    #weight unit FN
    ws.cell(row=rowNum, column=176).value = 18.50   #FT item_display_length
    ws.cell(row=rowNum, column=177).value = 0.70    #FU Item_display_width
    ws.cell(row=rowNum, column=179).value = 14.50   #FW Item Display Height
    ws.cell(row=rowNum, column=182).value = 1.70    #FZ Item Display Weight
    ws.cell(row=rowNum, column=183).value = 'LB'    #GA item display weight
    ws.cell(row=rowNum, column=186).value = 14.50   #GD item height
    ws.cell(row=rowNum, column=187).value = '18.50' #GE item length 
    ws.cell(row=rowNum, column=189).value = '0.70'  #GG item_width
    ws.cell(row=rowNum, column=205).value = gw      #GW fabric_type
    ws.cell(row=rowNum, column=235).value = 1.70    #IA item_weight
    today = date.today()
    ws.cell(row=rowNum, column=278).value = today.strftime("%m/%d/%y")   #JR Sale Start Date sale_from_date
    #(FM, FT, FU, FW, FZ, GD, GE, GG) GW IA JR
    count = count + 1
    wb.save("new_test.xlsx")
    return count #return worksheet so can save file at end.

#functions for Copy of Slide Model Pictures
def copyOfSlide1_VertHorizontal(inputImage):
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    width, height = innerImg.size 
    if width > height:
        modelImage = Image.open('Copy of Slide2.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (532,409) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (857,338))
    else:
        modelImage = Image.open('Copy of Slide1.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (410,534) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (919,274))
    namename, saveName = inputImage.split(".", 1)
    rgb_im.save(fp="./test/copyOfSlide1_2_" + os.path.basename(inputImage))
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test' #this should be a constant of some sort as its being accessed in every function. 
    fileBase = "copyOfSlide1_2_" + os.path.basename(inputImage)
    keyName = os.path.join(dir_name, fileBase)
    print("Pasted and saved")
    return keyName

def copyOfSlide2_VertHorizontal(inputImage):
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    width, height = innerImg.size 
    if width > height:
        modelImage = Image.open('Copy of Slide4.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (438,347) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (1526,534))
    else:
        modelImage = Image.open('Copy of Slide3.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (347,438) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (1573,513))
    namename, saveName = inputImage.split(".", 1)
    #print("Savename = ", saveName)
    rgb_im.save(fp="./test/copyOfSlide3_4_" + os.path.basename(inputImage))
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test' #this should be a constant of some sort as its being accessed in every function. 
    fileBase = "copyOfSlide3_4_" + os.path.basename(inputImage)
    keyName = os.path.join(dir_name, fileBase)
    print("Pasted and saved")
    return keyName

def copyOfSlide3_VertHorizontal(inputImage):
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    width, height = innerImg.size 
    if width > height:
        modelImage = Image.open('Copy of Slide6.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (469,361) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (1607,403))
    else:
        modelImage = Image.open('Copy of Slide5.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (361,469) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (1662,347))
    namename, saveName = inputImage.split(".", 1)
    rgb_im.save(fp="./test/copyOfSlide5_6_" + os.path.basename(inputImage) )
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test' 
    fileBase = "copyOfSlide5_6_" + os.path.basename(inputImage)
    keyName = os.path.join(dir_name, fileBase)
    print("Pasted and saved")
    return keyName

# %%
#This needs to be DEFINED. 2/28/21
def image7GenericArt(inputImage):
    innerImg = Image.open(inputImage) #open image object of image to be inserted 
    width, height = innerImg.size 
    num7BBPath = r'12x16 Black Bevel\12x16 Black Bevel\7.jpeg'
    if width > height:
        modelImage = Image.open('Copy of Slide6.jpeg')
        rgb_im = modelImage.convert('RGB')
        reSize = (469,361) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (1607,403))
    else:
        num7BB = Image.open(num7BBPath)
        rgb_im = num7BB.convert('RGB')
        reSize = (378,514) # size of image to be pasted into frame
        resizeImg = innerImg.resize(reSize)
        rgb_im.paste(resizeImg, (477,237))
    namename, saveName = inputImage.split(".", 1)
    rgb_im.save(fp="./test/num7_" + os.path.basename(inputImage) )
    dir_name = r'C:\Users\joton\OneDrive\Documents\Automation Project\test' 
    fileBase = "num7_" + os.path.basename(inputImage)
    keyName = os.path.join(dir_name, fileBase)
    print("Pasted and saved")
    return keyName

testImage = r'1 Times Images\Disney Princess.jpg'
image7GenericArt(testImage)
    # frameBF = Image.open(frameImage) #open Black Flat
    # bb1216 = r'12x16 Black Bevel\12x16 Black Bevel\1 Main.jpeg' #path to beveled black
    # wf1216 = r'12x16 White Flat\12x16 White Flat\1 Main.jpeg' #path to flat white frame
    # gf1216 = r'12x16 Grey Flat\12x16 Grey Flat\1 Main.jpeg'
    # frameBB1216 = Image.open(bb1216) #opens the black beveled fram 12 x 16
    # frameWF1216 = Image.open(wf1216) 
    # frameGF1216 = Image.open(gf1216)
# Out:
# Pasted and saved
# 'C:\\Users\\joton\\OneDrive\\Documents\\Automation Project\\test\\num7_Disney Princess.jpg'

# %%
import boto3
import uuid
s3_client = boto3.client('s3')
s3_resource = boto3.resource('s3')

def create_bucket_name(bucket_prefix):
    return ''.join([bucket_prefix, str(uuid.uuid4())])

#print(create_bucket_name('test_name'))

def create_bucket(bucket_prefix, s3_connection):
    session = boto3.session.Session()
    current_region = session.region_name
    bucket_name = create_bucket_name(bucket_prefix)
    if current_region == 'us-east-1':
        bucket_response = s3_connection.create_bucket(
            Bucket = bucket_name
        )
    else: 
        bucket_response = s3_connection.create_bucket(
            Bucket=bucket_name,
            CreateBucketConfiguration={
            'LocationConstraint': current_region})
    print(bucket_name, current_region)
    return bucket_name, bucket_response

def create_temp_file(size, file_name, file_content):
    random_file_name = ''.join([str(uuid.uuid4().hex[:6]), file_name])
    with open(random_file_name, 'w') as f:
        f.write(str(file_content) * size)
    return random_file_name

#first_file_name
first_bucket_name = 'firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe' # bucket to upload all images
#first_bucket = s3_resource.Bucket(name=first_bucket_name)


#first_bucket
#testImages = 'Main_Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg'
#first_object = s3_resource.Object(bucket_name = first_bucket_name, key = testImages)
#first_object_again = first_bucket.Object(first_file_name)
#first_bucket_name, first_response = create_bucket(bucket_prefix='firstpythonbucket', s3_connection=s3_resource.meta.client)

# %%
# first_object = s3_resource.Object(bucket_name = first_bucket_name, key = testImages)

# #first_object_again = first_bucket.Object('Main Image Horizontal.jpeg') #make an s3 object 
# first_bucket_again = first_object.Bucket() #Bucket 

# upload_file_path = Path('VVG-Horizontal\Main_Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg')
# first_object.upload_file(str(upload_file_path), ExtraArgs={
#     'ACL': 'public-read'}) #upload file to s3 

# up_path_2 = Path(r'VVG-Horizontal\Number2Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg')
# testimage2 = 'Number2Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg'
# second_object = s3_resource.Object(bucket_name = first_bucket_name, key = testimage2)
# second_object.upload_file(str(up_path_2), ExtraArgs={
#     'ACL': 'public-read'})

# up_path_3 = Path(r'VVG-Horizontal\Number3New_Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg')
# testimage3 = 'Number3New_Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg'
# third_object = s3_resource.Object(bucket_name = first_bucket_name, key = testimage3)
# third_object.upload_file(str(up_path_3), ExtraArgs={
#     'ACL': 'public-read'})

# up_path_4 = Path(r'VVG-Horizontal\number4_Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg')
# testimage4 = 'number4_Vincent Van Gogh  - 1886 - Bowl With Peonies And Roses.jpeg'
# third_object = s3_resource.Object(bucket_name = first_bucket_name, key = testimage4)
# third_object.upload_file(str(up_path_4), ExtraArgs={
#     'ACL': 'public-read'})

#image #6 should be used on all inputs
# number2 = '2.jpeg'
# third_object = s3_resource.Object(bucket_name = first_bucket_name, key = number2)
# third_object.upload_file(number2, ExtraArgs={  'ACL': 'public-read'})


#testimage6 = 'Number 7.jpeg'
# BB12x16_num2 = r'12x16 Black Bevel\12x16 Black Bevel\2.jpeg'
# third_object = s3_resource.Object(bucket_name = first_bucket_name, key = BB12x16_num2)
# third_object.upload_file(BB12x16_num2, ExtraArgs={  'ACL': 'public-read'})

#check if these are uploaded 
number6 = r'12x16 Black Bevel\12x16 Black Bevel\6.jpeg'
eighth_object = s3_resource.Object(bucket_name = first_bucket_name, key = number6)
eighth_object.upload_file(number6, ExtraArgs={  'ACL': 'public-read'})

number6_landscape = r'12x16 Black Bevel\12x16 Black Bevel\16.jpeg'
ninth_object = s3_resource.Object(bucket_name = first_bucket_name, key = number6_landscape)
ninth_object.upload_file(number6_landscape, ExtraArgs={  'ACL': 'public-read'})

#write_to_excel('https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Main_Vincent+Van+Gogh++-+1886+-+Bowl+With+Peonies+And+Roses.jpeg', 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Number2Vincent+Van+Gogh++-+1886+-+Bowl+With+Peonies+And+Roses.jpeg','https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Number3New_Vincent+Van+Gogh++-+1886+-+Bowl+With+Peonies+And+Roses.jpeg ', 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/number4_Vincent+Van+Gogh++-+1886+-+Bowl+With+Peonies+And+Roses.jpeg')

# %%
#https://bucket-name.s3.Region.amazonaws.com/key name


### CHECK THAT THE BUCKET UPLOADS WORK FOR ALL LIFE STYLE PHOTOS ###CHECKCHECEKCK!
def main():
    #print("This is main")
    import os
    portrait = True 
    imageFolder = input("Enter path to folder with images (.png or .jpg):")
    print("File Path Entered: ", imageFolder)
    path = imageFolder
    #  we shall store all the file names in this list
    filelist = []
    keynames = [] #store the returned keynames
    first_bucket_name = 'firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe'
    #set up workbook for write_to_excel
    count = 0 #count for write_to_excel function
    #load workbook and delete rows and save
    wb = load_workbook(filename = 'new_test.xlsx')
    ws = wb.active
    ws.delete_rows(4, 3)
    wb.save('new_test.xlsx')
    #ws.delete_rows(4, 3)
    for root, dirs, files in os.walk(path):
	    for file in files:
        #append the file name to the list
		    filelist.append(os.path.join(root,file))
    #print all the file names
    for name in filelist:
        
        innerImg = Image.open(name) #open image object of image to be inserted 
        width, height = innerImg.size 
        #CHECK FOR PORTRAIT OR LANSCAPE
        if width > height:
            portrait = False
            keynames = landscapeFrame('./Main Image Horizontal.jpeg', inputImg = name)
            for key in keynames:
                third_object = s3_resource.Object(bucket_name = first_bucket_name, key = os.path.basename(key))
                third_object.upload_file(key, ExtraArgs={'ACL': 'public-read'})
        else:
            keynames = modify12x16Frame(frameImage ='./Main Image Vertical.jpeg', inputImage = name)
            #print("keyName = ", keyName)
            for key in keynames:
                third_object = s3_resource.Object(bucket_name = first_bucket_name, key = os.path.basename(key))
                third_object.upload_file(key, ExtraArgs={'ACL': 'public-read'})
        #END IF BLOCK

        #URL for excel main photo
        # mainURL =  'https://' + first_bucket_name + '.s3-us-west-1.amazonaws.com/' + os.path.basename(keyName)
        # #lifestyle photo with dimensions 
        # key1 = number2VertHorizontal(name) #should return keyname to build the url 
        # print(key1) 
        # bucket_object = s3_resource.Object(bucket_name = first_bucket_name, key = os.path.basename(key1))
        # bucket_object.upload_file(key1, ExtraArgs={  'ACL': 'public-read'})
        # number2URL = 'https://' + first_bucket_name + '.s3-us-west-1.amazonaws.com/' + os.path.basename(key1)
        # #lifestyle photo
        # key2 = copyOfSlide1_VertHorizontal(name) #should return keyname to build the url 
        # bucket_object = s3_resource.Object(bucket_name = first_bucket_name, key = os.path.basename(key2))
        # bucket_object.upload_file(key2, ExtraArgs={  'ACL': 'public-read'})
        # #URL for CSV file
        # slide1URL = 'https://' + first_bucket_name + '.s3-us-west-1.amazonaws.com/' + os.path.basename(key2)
        # #Next Lifestle Photos
        # key3 = copyOfSlide2_VertHorizontal(name) # should be the keyname
        # bucket_object = s3_resource.Object(bucket_name = first_bucket_name, key = os.path.basename(key3))
        # bucket_object.upload_file(key3, ExtraArgs={  'ACL': 'public-read'})
        # slide2URL = 'https://' + first_bucket_name + '.s3-us-west-1.amazonaws.com/' + os.path.basename(key3)
        # #Next Lifestyle Photo
        # key4 = copyOfSlide3_VertHorizontal(name) #keyname is path to image
        # bucket_object = s3_resource.Object(bucket_name = first_bucket_name, key = os.path.basename(key4))
        # bucket_object.upload_file(key4, ExtraArgs={  'ACL': 'public-read'})
        # slide3URL = 'https://' + first_bucket_name + '.s3-us-west-1.amazonaws.com/' + os.path.basename(key4)
        #get name for writing to excel
        nameOfFile = os.path.basename(keyName)
        (nameOfFile, ext) = os.path.splitext(nameOfFile)
        item_name, color_name, gw = titletype(nameOfFile)

        ##### This image order is following the sheets Sizing Info For Jotony
        if (portrait): 
            number2URL = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/12x16+Black+Bevel%5C12x16+Black+Bevel%5C2.jpeg'
            number6URL = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/12x16+Black+Bevel%5C12x16+Black+Bevel%5C6.jpeg'
        else:
            number2URL = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/12x16+Black+Bevel%5C12x16+Black+Bevel%5C12.jpeg'
            number6URL = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/12x16+Black+Bevel%5C12x16+Black+Bevel%5C16.jpeg'

        NuveauDiscount =  'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Nuveau+Discount.jpg'
        NuveauQuality = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Nuveau+Quality.jpeg'
        AboutNuveau = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/About+Nuveau.jpg'
        
        #scope is wack, updating count to iterate through rows of excel
        #NEED NUMBER 7 FOR TODAY 3/6/21
        count = write_to_excel(item_name, mainURL, number2URL, NuveauDiscount , AboutNuveau, NuveauQuality, number6URL, count, color_name, gw)
        print("Count = ", count)
    
    #excelName = input("Enter excel file name: ")
    #wb.save(f'{excelName}.xlsx')
    print("Worksheet saved and Program Finished")
if __name__ == "__main__":
    main()
# Out:
# File Path Entered:  testImages
# File saved and changed
# Pasted and saved
# C:\Users\joton\OneDrive\Documents\Automation Project\test\Number2Bedroom In Arles_by Vincent Van Gogh!RANDOM ISH.jpeg
# Pasted and saved
# Pasted and saved
# Pasted and saved
# Original string:  Bedroom In Arles_by Vincent Van Gogh!RANDOM ISH
# OG string length =  36
# Count =  1
# File saved and changed
# Pasted and saved
# C:\Users\joton\OneDrive\Documents\Automation Project\test\Number2Bowl With Peonies And Roses_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg
# Pasted and saved
# Pasted and saved
# Pasted and saved
# Original string:  Bowl With Peonies And Roses_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5
# OG string length =  47
# Count =  2
# File saved and changed
# keyName =  C:\Users\joton\OneDrive\Documents\Automation Project\test\Sunflowers_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg
# Pasted and saved
# ...

# %%
#function parses title name and then returns the desired title for the csv file.
def titletype(filename):
    #parse string to remove special characters 
    str = filename
    print("Original string: ", str)
    #print("OG string length = ", len(str))
    #res_str = str.replace(';', '')
    #Print Size: 12" x 16" Frame Size: 14.5" x 18.5"
    color_nameDI, left_over = str.split("_", 1)
    title_nameD, GW = str.split('!', 1) #right side of split is info to be placed in GW column of excel
    title_nameD = title_nameD.replace('!', ' ') #removes unecessary chars from title. 
    title_nameD = title_nameD.replace('_', ' ')
    print("OG string length = ", len(title_nameD))
    #conditionals to check length of title and add title info that matches the length of the existing string
    if len(title_nameD) >= 65:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 58:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 56:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home Design Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 51:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 47:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Room Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 39:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift for Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 30:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Picture Gift for Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 24:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 22:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift for Bedroom & Living Room Walls"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 16:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Picture Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    else:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Picture Gift for Bedroom & Living Room Walls"
        return title_nameD, color_nameDI, GW

testtitle = "Sunflowers_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg"
item_name, color_name, gw = titletype(testtitle)
print(item_name)


def Bathroomtype(filename):
    #parse string to remove special characters 
    str = filename
    print("Original string: ", str)
    #print("OG string length = ", len(str))
    #res_str = str.replace(';', '')
    #Print Size: 12" x 16" Frame Size: 14.5" x 18.5"
    color_nameDI, left_over = str.split("_", 1)
    title_nameD, GW = str.split('!', 1) #right side of split is info to be placed in GW column of excel
    title_nameD = title_nameD.replace('!', ' ') #removes unecessary chars from title. 
    title_nameD = title_nameD.replace('_', ' ')
    print("OG string length = ", len(title_nameD))
    #conditionals to check length of title and add title info that matches the length of the existing string
    if len(title_nameD) >= 112:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Picture & Cool Artwork Decoration Gift | Unique & Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 108:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 104:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 99:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Quotes"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 94:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Quotes Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 89:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Quotes & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 87:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Quotes & Sayings Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 82:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Quotes & Sayings Gift"
        return title_nameD, color_nameDI, GW
    
    if len(title_nameD) == 81:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Quotes, Signs & Sayings Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 79:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Funny Quotes, Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 74:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Artwork Quotes, Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 66:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Artwork Quotes, Signs & Sayings Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 63:
        title_nameD += "  Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Quotes Artwork Decorations | Signs & Sayings"
        return title_nameD, color_nameDI, GW
    if len(title_nameD) == 62:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Artwork Gift | Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 57:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Artwork | Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 55:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Artwork Gift | Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 50:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Artwork Quotes | Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 43:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Artwork Decorations | Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 41:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Artwork Decorations | Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 34:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Artwork Gift | Unique & Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 30:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Cool Quotes & Aesthetic Artwork Gift | Unique & Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 23:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Artwork Decoration Gift | Unique & Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 20:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Cool & Aesthetic Quotes Artwork Decoration Gift | Unique & Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 14:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Picture & Artwork Decoration Gift | Unique & Quirky Signs & Sayings"
        return title_nameD, color_nameDI, GW
    else:
        title_nameD += " Bathroom Poster Wall Art Decor Framed Print | Funny Restroom Quote Posters, Pictures & Prints | Aesthetic Quotes Picture & Cool Artwork Decoration Gift | Unique & Quirky Signs & Sayings"

testtitle = "Sunflowers_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg"
item_name, color_name, gw = titletype(testtitle)
print(item_name)

def QuoteArt_TitleType(filename):
    #parse string to remove special characters 
    str = filename
    print("Original string: ", str)
    #print("OG string length = ", len(str))
    #res_str = str.replace(';', '')
    #Print Size: 12" x 16" Frame Size: 14.5" x 18.5"
    color_nameDI, left_over = str.split("_", 1)
    title_nameD, GW = str.split('!', 1) #right side of split is info to be placed in GW column of excel
    title_nameD = title_nameD.replace('!', ' ') #removes unecessary chars from title. 
    title_nameD = title_nameD.replace('_', ' ')
    print("OG string length = ", len(title_nameD))
    #conditionals to check length of title and add title info that matches the length of the existing string
    if len(title_nameD) >= 103:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork | Cool & Original Quote Posters, Pictures & Prints in Frame | Gift for Bedroom, Bathroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 98:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Quote Posters"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 95:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Cool Quote Posters"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 92:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Bedroom Quote Posters"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 84:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Quote Posters & Pictures"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 79:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Quote Posters, Pictures & Prints"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 75:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Cool Quote Posters, Pictures & Prints"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 67:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Quote Posters, Pictures & Prints in Frame"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 62:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes | Bedroom Quote Posters, Pictures & Prints in Frame"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 57:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Gift | Bedroom Quote Posters, Pictures & Prints in Frame"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 54:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Gift | Cool Bedroom Quote Posters, Pictures & Prints in Frame"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 49:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork Gift | Bedroom Quote Posters, Pictures & Prints in Frame"
        return title_nameD, color_nameDI, GW

    if len(title_nameD) == 48:
        title_nameD += " Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Room Gift"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 43:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork | Quote Posters, Pictures & Prints in Frame | Gift for Bedroom"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 32:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork | Cool Quote Posters, Pictures & Prints in Frame | Gift for Bedroom"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 29:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork | Cool Quote Posters, Pictures & Prints in Frame | Gift for Bedroom & Bathroom"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 19:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork | Cool Quote Posters, Pictures & Prints in Frame | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 8:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork | Cool Quote Posters, Pictures & Prints in Frame | Gift for Bedroom, Bathroom & Living Room"
        return title_nameD, color_nameDI, GW
    else:
        title_nameD += " Poster Wall Art Decor Framed Print | Inspirational & Motivational Positive Quotes Artwork | Cool & Original Quote Posters, Pictures & Prints in Frame | Gift for Bedroom, Bathroom & Living Room"
        return title_nameD, color_nameDI, GW

testtitle = "Sunflowers_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg"
item_name, color_name, gw = titletype(testtitle)
print(item_name)

def Generic_TitleType(filename):
    #parse string to remove special characters 
    str = filename
    print("Original string: ", str)
    #print("OG string length = ", len(str))
    #res_str = str.replace(';', '')
    #Print Size: 12" x 16" Frame Size: 14.5" x 18.5"
    color_nameDI, left_over = str.split("_", 1)
    title_nameD, GW = str.split('!', 1) #right side of split is info to be placed in GW column of excel
    title_nameD = title_nameD.replace('!', ' ') #removes unecessary chars from title. 
    title_nameD = title_nameD.replace('_', ' ')
    print("OG string length = ", len(title_nameD))
    #conditionals to check length of title and add title info that matches the length of the existing string
    if len(title_nameD) >= 111:
        title_nameD += "Poster Wall Art Decor Framed Print | Posters, Pictures & Prints for Bedroom Poster Wall Art Decor Framed Print | Posters, Pictures & Prints for Bedroom & Living Room Poster Wall Art Decor Framed Print | Posters, Pictures & Prints | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 104:
        title_nameD += " Poster Wall Art Decor Framed Print | Posters, Pictures & Prints for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 98:
        title_nameD += " Poster Wall Art Decor Framed Print | Posters, Pictures & Prints | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 96:
        title_nameD += " Poster Wall Art Decor Framed Print | Cool Posters, Pictures & Prints | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 94:
        title_nameD += " Poster Wall Art Decor Framed Print | Office Posters, Pictures & Prints | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 89:
        title_nameD += " Poster Wall Art Decor Framed Print | Posters, Pictures & Prints in Frame | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 83:
        title_nameD += " Poster Wall Art Decor Framed Print | Cool Posters, Pictures & Prints in Frame | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 78:
        title_nameD += " Poster Wall Art Decor Framed Print | Decoration Posters, Pictures & Prints in Frame | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 74:
        title_nameD += " Poster Wall Art Decor Framed Print | Home Decoration Posters, Pictures & Prints in Frame | Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW

    if len(title_nameD) == 73:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | For Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 65:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Gift for Bedroom"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 62:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Merchandise Gift for Bedroom Walls"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 57:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Merchandise for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 52:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Merchandise Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW

    elif len(title_nameD) >= 47:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Merchandise for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW

    elif len(title_nameD) >= 44:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Merchandise Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 39:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Artwork Merchandise for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW

    elif len(title_nameD) >= 34:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Artwork Merchandise Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW

    elif len(title_nameD) >= 29:
        title_nameD += " Poster Wall Art Decor Framed Print | Cool Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Artwork Merchandise Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 24:
        title_nameD += " Poster Wall Art Decor Framed Print | Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Picture & Artwork Merchandise Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    elif len(title_nameD) >= 11:
        title_nameD += " Poster Wall Art Decor Framed Print | Cool Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Picture & Artwork Merchandise Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW
    else:
        title_nameD += " Poster Wall Art Decor Framed Print | Cool Motivational Home & Office Decoration Posters, Pictures & Prints in Frame | Aesthetic Picture & Artwork Merchandise Gift for Bedroom & Living Room"
        return title_nameD, color_nameDI, GW

testtitle = "Sunflowers_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg"
item_name, color_name, gw = titletype(testtitle)
print(item_name)



#3 presents
#2 prompts 
#3 different templates 
#1 - Fine Artwork
#2 - generic Artwork
#3 - "Quote" Art    
### Different Keywords. 
#CSV is always the same.

#NO HYPEN _ and ! 

#SEt everything to F1-Random_SKU 

#SYMBOL FOR COLOR NAME = ; #
#everything before colon is color name
#everything until semicolon - is beginning of title
#do not include the symbols into the title. 
#after the second symbol it is fabric_type column. GW

#ROW 4 should be 
#inserts should be below that. 
                                                        #Image URLS
#COLUMNS to have values inserted: C()B(SKU), D(Item Name), L M O P Q R S T, DI(color name), DK(size), EO, EP, (FM, FT, FU, FW, FZ, GD, GE, GG) GW IA(Weight) JR(Sale start Date) Change to 1-1-2021
#INputs should come from images. 

#space is included in title. 

#GW text is in fb messenger and use | for seperate. 

#If 15 Characters or less Use 

#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Picture Gift for Bedroom & Living Room Walls


# If 16 -21
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Picture Gift for Bedroom & Living Room


# 22 or 23
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift for Bedroom & Living Room Walls

# 24- 29
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift for Bedroom & Living Room

# 30-38
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Picture Gift for Room

# 39-46
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift for Room

# 47 - 50
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Room Gift

# 51-55
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Gift

# 56 -57
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home Design Gift

# 58 -64
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home Gift

# 65 -76
#  Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame


#DK - NEED the seperate type listing in order to get the info to put in this cell - "Black beveld ------" and so on. 21 different listing options for this cell.

#GW will always of print size and frame size + additional info -> Need to add additional info next print size and frame size = Print Size xx Frame Size xx + Additional info. 

#IA depends on the print size and frame size 


#Compress Image Files!

#Accept different file type besides .png and .jpeg. => extreme low priority 

#future translate CSV for other software/websites.

#Different lifestyle determined for the whole batch of images. ASK FOR INPUT (FINE ART, QUOTE ART, GENERIC, BATHROOM ART)


#add filter to images. 
#signature.
# Out:
# Original string:  Sunflowers_by Vincent Van Gogh!Print Size 12 x 16 Frame Size 14.5 x 18.5.jpeg
# OG string length =  30
# Sunflowers by Vincent Van Gogh Framed Print Poster Wall Art Decor | Fine Artwork Painting Reproduction Posters Pictures & Canvas | Gallery Prints in Frame | Home & Office Picture Gift for Room

# %%
import requests
import json 

api_key = 'fb9fcb3ceeb6ef791a21ade3cc05b3f1e7a383a5'
API_ENDPOINT = 'https://api.letsenhance.io/v1/pipeline' #POST

request = requests.post(url=API_ENDPOINT, json= "./snippet.json")

f = open('snippet.json',)  
data = json.load(f) 
print(json.dumps(data, indent = 1)) 

print(request.text)
print(request.status_code)
# Out:
# {
#  "x-api-key": "fb9fcb3ceeb6ef791a21ade3cc05b3f1e7a383a5",
#  "source": {
#   "http": {
#    "url": "https://test-lets-enhance-image-bucket.s3-us-west-2.amazonaws.com/Baby+Yoda.jpg"
#   }
#  },
#  "notify_url": "http://example.com/le-webhook",
#  "operations": [
#   {
#    "op": "nn/sorcerer",
#    "width": 1600,
#    "height": 900,
#    "upscale": 2.0
#   },
#   {
#    "op": "img/set_metadata",
#    "dpi": 120
#   },
#   {
#    "op": "img/encode",
#    "format": "JPEG",
#    "format_opts": {
#     "quality": 90
#    }
#   }
#  ],
#  "sink": {
#   "temp_store": true
#  }
# }
# {"message":"forbidden"}
# 401

# %%
def write_to_excel12x16bf(nameOfImage, mainImage, number2Image, number3Image, number4Image, number5Image, count, colorname, gw="Print Size 12 x 16 Frame Size 14.5 x 18.5"):
    #data = pd.read_excel(filename)
    #data.to_excel('test_write_excel.xlsx', index=False)
    wb = load_workbook(filename = 'new_test.xlsx')
    ws = wb.active
    # ws.delete_rows(4, 3)
    rowNum = 5 + count
    #print("Rown Num = ", rowNum)
    ws.cell(row=rowNum, column=1).value = 'Home'
    ws.cell(row=rowNum, column=2).value = randomSKU()
    ws.cell(row=rowNum, column=4).value = nameOfImage 
    ws.cell(row=rowNum, column=12).value = mainImage
    ws.cell(row=rowNum, column=13).value = number2Image
    ws.cell(row=rowNum, column=14).value = number3Image
    ws.cell(row=rowNum, column=15).value = number4Image
    ws.cell(row=rowNum, column=16).value = number5Image
    ws.cell(row=rowNum, column=17).value = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Number+6.jpeg'
    ws.cell(row=rowNum, column=18).value = 'https://firstpythonbucket04b0a6cb-4b38-4cc9-b7f1-9dd3f9f21afe.s3-us-west-1.amazonaws.com/Number+7.jpeg'
    ws.cell(row=rowNum, column=113).value = colorname
    ws.cell(row=rowNum, column=115).value = '14.5 x 18.5 inches' #DK size_name
    ws.cell(row=rowNum, column=145).value = "18.5 inches"#EO length range
    ws.cell(row=rowNum, column=146).value = "16.5 inches"#EP Width Range
    #ws.cell(row=rowNum, column=205).value = 'Print Size 12" x 16" Frame Size 14.5" x 18.5"' #GW Width Range 
    ws.cell(row=rowNum, column=169).value = 1.70    #Shipping weight FM
    ws.cell(row=rowNum, column=169).value = 'LB'    #weight unit FN
    ws.cell(row=rowNum, column=176).value = 18.50   #FT item_display_length
    ws.cell(row=rowNum, column=177).value = 0.70    #FU Item_display_width
    ws.cell(row=rowNum, column=179).value = 14.50   #FW Item Display Height
    ws.cell(row=rowNum, column=182).value = 1.70    #FZ Item Display Weight
    ws.cell(row=rowNum, column=183).value = 'LB'    #GA item display weight
    ws.cell(row=rowNum, column=186).value = 14.50   #GD item height
    ws.cell(row=rowNum, column=187).value = '18.50' #GE item length 
    ws.cell(row=rowNum, column=189).value = '0.70'  #GG item_width
    ws.cell(row=rowNum, column=205).value = gw      #GW fabric_type
    ws.cell(row=rowNum, column=235).value = 1.70    #IA item_weight
    today = date.today()
    ws.cell(row=rowNum, column=278).value = today.strftime("%m/%d/%y")   #JR Sale Start Date sale_from_date
    #(FM, FT, FU, FW, FZ, GD, GE, GG) GW IA JR
    count = count + 1
    wb.save("new_test.xlsx")
    return count #return worksheet so can save file at end.
